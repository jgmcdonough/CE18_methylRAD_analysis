# %%
library(ggplot2)
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2     ✔ tidyr     1.3.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
data <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_MethylRAD_analysis_2018/analysis/ce_hc.csv')
head(data)
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “incomplete final line found by readTableHeader on '/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_MethylRAD_analysis_2018/analysis/Untitled spreadsheet - Sheet1.csv'”
#   Phase.1 Phase.2 diff..me.genes
# 1 control control   4
# 2 control hypoxic   7
# 3 hypoxic control 286
# 4 hypoxic hypoxic 478

# %%
colnames(data) = c('Phase1', 'Phase2', 'N_diff_me_genes')
data
# Out:
#   Phase1  Phase2  N_diff_me_genes
# 1 control control   4
# 2 control hypoxic   7
# 3 hypoxic control 286
# 4 hypoxic hypoxic 478

# %%
ggplot(data, aes(x = Phase1, fill = Phase2, y=N_diff_me_genes)) +
geom_bar(stat='identity',position = "dodge") +
theme_classic() +
##facet_grid(. ~Phase1) +
labs(x='Phase 1 Treatment', y="Significantly Differentially Methylated Genes (count)", fill='Phase 2 Treatment',
    title='Evidence of CE in Hypoxic Treatment')
# Out:
# plot without title
