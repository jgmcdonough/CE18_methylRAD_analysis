# %% [markdown]
# # sig DMGs and GOslim terms
#
# I want to better understand what processes sig. DMGs are mostly involved in for each pairwise comparison and overall for hypoxic stress. I've been doing this in excel, but think it will be easier in R.

# %% [markdown]
# #### I. load and prep

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ forcats   1.0.0     ✔ readr     2.1.4
# ✔ ggplot2   3.5.1     ✔ stringr   1.5.1
# ✔ lubridate 1.9.3     ✔ tibble    3.2.1
# ✔ purrr     1.0.2
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
# load df
dmgs <- read.csv('/project/pi_sarah_gignouxwolfsohn_uml_edu/julia/CE_MethylRAD_analysis_2018/analysis/deseq_res_files/GO_terms/sigDMG.goSlim.csv')
head(dmgs)
# Out:
#   gene_id      order
# 1 LOC111117760 1
# 2 LOC111119327 2
# 3 LOC111123492 3
# 4 LOC111123492 3
# 5 LOC111123492 3
# 6 LOC111123492 3
#   name
# 1 disintegrin and metalloproteinase domain-containing protein 10-like, transcript variant X3
# 2 calcyphosin-like protein, transcript variant X3
# 3 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 4 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 5 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 6 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
#   pair_vs_HC gene_name
# 1 CH, HH, CC ADAM10
# 2 CH, HH, CC CAPSL
# 3 CH, HH, CC PBX1
# 4 CH, HH, CC PBX1
# 5 CH, HH, CC PBX1
# 6 CH, HH, CC PBX1
#   process                                                   notes GO.IDs
# 1 cell signaling, adhesion, migration                             GO:0007219
# 2 calcium ion binding                                             NA
# 3 regulates embryonic development and cellular differention       GO:0048568
# 4 regulates embryonic development and cellular differention       GO:0009887
# 5 regulates embryonic development and cellular differention       GO:0048666
# 6 regulates embryonic development and cellular differention       GO:0048666
#   GOslim                Term
# 1 GO:0023052            signaling
# 2 NA                    NA
# 3 GO:0048856            anatomical structure development
# 4 GO:0048856            anatomical structure development
# 5 GO:0030154;GO:0048856 cell differentiation
# 6 GO:0030154;GO:0048856 anatomical structure development

# %% [markdown]
# #### II. Assigning treatment variables

# %%
cc <- dmgs %>% 
  filter(grepl("CC", pair_vs_HC))

ch <- dmgs %>% 
  filter(grepl("CH", pair_vs_HC))

hh <- dmgs %>% 
  filter(grepl("HH", pair_vs_HC))

# %%
head(hh)
# Out:
#   gene_id      order
# 1 LOC111117760 1
# 2 LOC111119327 2
# 3 LOC111123492 3
# 4 LOC111123492 3
# 5 LOC111123492 3
# 6 LOC111123492 3
#   name
# 1 disintegrin and metalloproteinase domain-containing protein 10-like, transcript variant X3
# 2 calcyphosin-like protein, transcript variant X3
# 3 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 4 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 5 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 6 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
#   pair_vs_HC gene_name
# 1 CH, HH, CC ADAM10
# 2 CH, HH, CC CAPSL
# 3 CH, HH, CC PBX1
# 4 CH, HH, CC PBX1
# 5 CH, HH, CC PBX1
# 6 CH, HH, CC PBX1
#   process                                                   notes GO.IDs
# 1 cell signaling, adhesion, migration                             GO:0007219
# 2 calcium ion binding                                             NA
# 3 regulates embryonic development and cellular differention       GO:0048568
# 4 regulates embryonic development and cellular differention       GO:0009887
# 5 regulates embryonic development and cellular differention       GO:0048666
# 6 regulates embryonic development and cellular differention       GO:0048666
#   GOslim                Term
# 1 GO:0023052            signaling
# 2 NA                    NA
# 3 GO:0048856            anatomical structure development
# 4 GO:0048856            anatomical structure development
# 5 GO:0030154;GO:0048856 cell differentiation
# 6 GO:0030154;GO:0048856 anatomical structure development

# %% [markdown]
# #### III. Counts of GOslim terms by treatment combination

# %%
cc.TermCounts <- cc %>% 
  count(Term) %>% # count freq of term
arrange(desc(n)) %>% # arrange most to least
mutate(label = 'CC vs. HC') %>% # add column for pairwise comparison
mutate(Percent = n / sum(n) * 100) %>%  # calc. percent
as.data.frame() # convert to data frame

cc.TermCounts
# Out:
#   Term                                      n label     Percent
# 1 NA                                        7 CC vs. HC 41.176471
# 2 anatomical structure development          3 CC vs. HC 17.647059
# 3 signaling                                 2 CC vs. HC 11.764706
# 4 DNA-templated transcription               1 CC vs. HC  5.882353
# 5 cell differentiation                      1 CC vs. HC  5.882353
# 6 protein catabolic process                 1 CC vs. HC  5.882353
# 7 regulation of DNA-templated transcription 1 CC vs. HC  5.882353
# 8 vesicle-mediated transport                1 CC vs. HC  5.882353

# %%
ch.TermCounts <- ch %>% 
  count(Term) %>% # count freq of term
arrange(desc(n)) %>% # arrange most to least
mutate(label = 'CH vs. HC') %>% # add column for pairwise comparison
mutate(Percent = n / sum(n) * 100) %>%  # calc. percent
as.data.frame() # convert to data frame

ch.TermCounts
# Out:
#    Term                                                   n   label
# 1  NA                                                     115 CH vs. HC
# 2  signaling                                               17 CH vs. HC
# 3  DNA-templated transcription                             10 CH vs. HC
# 4  anatomical structure development                         8 CH vs. HC
# 5  protein catabolic process                                8 CH vs. HC
# 6  intracellular protein transport                          7 CH vs. HC
# 7  regulation of DNA-templated transcription                7 CH vs. HC
# 8  DNA repair                                               6 CH vs. HC
# 9  ribosome biogenesis                                      6 CH vs. HC
# 10 mitotic cell cycle                                       5 CH vs. HC
# 11 protein-containing complex assembly                      5 CH vs. HC
# 12 vesicle-mediated transport                               5 CH vs. HC
# 13 carbohydrate derivative metabolic process                4 CH vs. HC
# 14 cytoskeleton organization                                4 CH vs. HC
# 15 generation of precursor metabolites and energy           4 CH vs. HC
# 16 lipid metabolic process                                  4 CH vs. HC
# 17 mRNA metabolic process                                   4 CH vs. HC
# 18 protein maturation                                       4 CH vs. HC
# 19 amino acid metabolic process                             3 CH vs. HC
# 20 cell differentiation                                     3 CH vs. HC
# 21 nucleobase-containing small molecule metabolic process   3 CH vs. HC
# 22 snRNA metabolic process                                  3 CH vs. HC
# 23 transmembrane transport                                  3 CH vs. HC
# 24 DNA replication                                          2 CH vs. HC
# 25 carbohydrate metabolic process                           2 CH vs. HC
# 26 cytoplasmic translation                                  2 CH vs. HC
# 27 protein folding                                          2 CH vs. HC
# 28 reproductive process                                     2 CH vs. HC
# 29 sulfur compound metabolic process                        2 CH vs. HC
# 30 vitamin metabolic process                                2 CH vs. HC
# 31 DNA recombination                                        1 CH vs. HC
# 32 chromosome segregation                                   1 CH vs. HC
# 33 cilium organization                                      1 CH vs. HC
# 34 membrane organization                                    1 CH vs. HC
# 35 mitochondrial gene expression                            1 CH vs. HC
# 36 mitotic nuclear division                                 1 CH vs. HC
# 37 nucleocytoplasmic transport                              1 CH vs. HC
# 38 peroxisome organization                                  1 CH vs. HC
# 39 programmed cell death                                    1 CH vs. HC
# 40 protein glycosylation                                    1 CH vs. HC
# 41 regulatory ncRNA-mediated gene silencing                 1 CH vs. HC
#    Percent
# 1  43.7262357
# 2   6.4638783
# 3   3.8022814
# 4   3.0418251
# 5   3.0418251
# 6   2.6615970
# 7   2.6615970
# 8   2.2813688
# 9   2.2813688
# 10  1.9011407
# 11  1.9011407
# 12  1.9011407
# 13  1.5209125
# 14  1.5209125
# 15  1.5209125
# 16  1.5209125
# 17  1.5209125
# 18  1.5209125
# 19  1.1406844
# 20  1.1406844
# 21  1.1406844
# 22  1.1406844
# 23  1.1406844
# 24  0.7604563
# 25  0.7604563
# 26  0.7604563
# 27  0.7604563
# 28  0.7604563
# 29  0.7604563
# 30  0.7604563
# 31  0.3802281
# 32  0.3802281
# 33  0.3802281
# 34  0.3802281
# 35  0.3802281
# 36  0.3802281
# 37  0.3802281
# 38  0.3802281
# 39  0.3802281
# 40  0.3802281
# 41  0.3802281

# %%
hh.TermCounts <- hh %>% 
  count(Term) %>% # count freq of term
arrange(desc(n)) %>% # arrange most to least
mutate(label = 'HH vs. HC') %>% # add column for pairwise comparison
mutate(Percent = n / sum(n) * 100) %>%  # calc. percent
as.data.frame() # convert to data frame

hh.TermCounts
# Out:
#    Term                                                   n  label
# 1  NA                                                     40 HH vs. HC
# 2  anatomical structure development                        7 HH vs. HC
# 3  signaling                                               7 HH vs. HC
# 4  DNA-templated transcription                             4 HH vs. HC
# 5  carbohydrate derivative metabolic process               4 HH vs. HC
# 6  intracellular protein transport                         4 HH vs. HC
# 7  mRNA metabolic process                                  4 HH vs. HC
# 8  regulation of DNA-templated transcription               4 HH vs. HC
# 9  lipid metabolic process                                 3 HH vs. HC
# 10 protein catabolic process                               3 HH vs. HC
# 11 ribosome biogenesis                                     3 HH vs. HC
# 12 amino acid metabolic process                            2 HH vs. HC
# 13 cell differentiation                                    2 HH vs. HC
# 14 nucleocytoplasmic transport                             2 HH vs. HC
# 15 protein-containing complex assembly                     2 HH vs. HC
# 16 DNA replication                                         1 HH vs. HC
# 17 carbohydrate metabolic process                          1 HH vs. HC
# 18 cell adhesion                                           1 HH vs. HC
# 19 cilium organization                                     1 HH vs. HC
# 20 cytokinesis                                             1 HH vs. HC
# 21 cytoskeleton organization                               1 HH vs. HC
# 22 mitochondrial gene expression                           1 HH vs. HC
# 23 mitochondrion organization                              1 HH vs. HC
# 24 mitotic cell cycle                                      1 HH vs. HC
# 25 nucleobase-containing small molecule metabolic process  1 HH vs. HC
# 26 protein glycosylation                                   1 HH vs. HC
# 27 regulatory ncRNA-mediated gene silencing                1 HH vs. HC
# 28 snRNA metabolic process                                 1 HH vs. HC
# 29 transmembrane transport                                 1 HH vs. HC
# 30 vesicle-mediated transport                              1 HH vs. HC
#    Percent
# 1  37.7358491
# 2   6.6037736
# 3   6.6037736
# 4   3.7735849
# 5   3.7735849
# 6   3.7735849
# 7   3.7735849
# 8   3.7735849
# 9   2.8301887
# 10  2.8301887
# 11  2.8301887
# 12  1.8867925
# 13  1.8867925
# 14  1.8867925
# 15  1.8867925
# 16  0.9433962
# 17  0.9433962
# 18  0.9433962
# 19  0.9433962
# 20  0.9433962
# 21  0.9433962
# 22  0.9433962
# 23  0.9433962
# 24  0.9433962
# 25  0.9433962
# 26  0.9433962
# 27  0.9433962
# 28  0.9433962
# 29  0.9433962
# 30  0.9433962

# %% [markdown]
# merge back into one df

# %%
merged.dmg <- rbind(cc.TermCounts, ch.TermCounts) %>%
rbind(hh.TermCounts)

dim(merged.dmg)
head(merged.dmg)
# Out:
# [1] 79  4
#   Term                             n label     Percent
# 1 NA                               7 CC vs. HC 41.176471
# 2 anatomical structure development 3 CC vs. HC 17.647059
# 3 signaling                        2 CC vs. HC 11.764706
# 4 DNA-templated transcription      1 CC vs. HC  5.882353
# 5 cell differentiation             1 CC vs. HC  5.882353
# 6 protein catabolic process        1 CC vs. HC  5.882353

# %% [markdown]
# #### IV. Visualize counts of terms

# %% [markdown]
# remove NAs to see better

# %%
options(repr.plot.width=15, repr.plot.height=10)

ggplot(na.omit(merged.dmg), aes(x=Term, y = Percent, fill = label)) +
geom_col() +
facet_wrap(~label) +
coord_flip() +
guides(fill = 'none') +
scale_fill_manual(values = c('cornflowerblue',  'mediumpurple', 'deeppink2')) +
labs(y = 'Percent of sig. DMGs',
    x = '') +
theme_bw() +
theme(strip.text = element_text(size = 15))
# Out:
# plot without title

# %% [markdown]
# this just looks too busy - would like to break it down into broader categories so there's less terms...
#
# Also, above is any DMG that was identified as significant in that pair - it might be interesting to look at what isn't shared, what is uniquely differentially methylated in that comparison...

# %% [markdown]
# ### unique DMG
#
# starting with CH vs. HC

# %%
unique_cc <- dmgs %>%
filter(pair_vs_HC == 'CH') %>%
count(Term) %>%
arrange(desc(n)) %>%
mutate(percent = n/sum(n) * 100) %>%
as.data.frame()

head(unique_cc)
# Out:
#   Term                                      n  percent
# 1 NA                                        79 42.021277
# 2 signaling                                 12  6.382979
# 3 DNA-templated transcription                9  4.787234
# 4 protein catabolic process                  7  3.723404
# 5 DNA repair                                 6  3.191489
# 6 regulation of DNA-templated transcription  6  3.191489

# %%
ggplot(na.omit(unique_cc),
       aes(x = fct_reorder(Term, percent, .desc = FALSE),
           y = percent)) + 
geom_col() + 
coord_flip() +
labs(x = 'GO Slim Term',
    y = 'Percent') +
theme_bw(base_size = 20)
# Out:
# plot without title

# %%
head(dmgs)
# Out:
#   gene_id      order
# 1 LOC111117760 1
# 2 LOC111119327 2
# 3 LOC111123492 3
# 4 LOC111123492 3
# 5 LOC111123492 3
# 6 LOC111123492 3
#   name
# 1 disintegrin and metalloproteinase domain-containing protein 10-like, transcript variant X3
# 2 calcyphosin-like protein, transcript variant X3
# 3 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 4 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 5 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 6 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
#   pair_vs_HC gene_name
# 1 CH, HH, CC ADAM10
# 2 CH, HH, CC CAPSL
# 3 CH, HH, CC PBX1
# 4 CH, HH, CC PBX1
# 5 CH, HH, CC PBX1
# 6 CH, HH, CC PBX1
#   process                                                   notes GO.IDs
# 1 cell signaling, adhesion, migration                             GO:0007219
# 2 calcium ion binding                                             NA
# 3 regulates embryonic development and cellular differention       GO:0048568
# 4 regulates embryonic development and cellular differention       GO:0009887
# 5 regulates embryonic development and cellular differention       GO:0048666
# 6 regulates embryonic development and cellular differention       GO:0048666
#   GOslim                Term
# 1 GO:0023052            signaling
# 2 NA                    NA
# 3 GO:0048856            anatomical structure development
# 4 GO:0048856            anatomical structure development
# 5 GO:0030154;GO:0048856 cell differentiation
# 6 GO:0030154;GO:0048856 anatomical structure development

# %%
flat.dmgs <- dmgs %>% 
separate_rows(!!sym('GOslim'), sep = ";")

head(flat.dmgs)
# Out:
#   gene_id      order
# 1 LOC111117760 1
# 2 LOC111119327 2
# 3 LOC111123492 3
# 4 LOC111123492 3
# 5 LOC111123492 3
# 6 LOC111123492 3
#   name
# 1 disintegrin and metalloproteinase domain-containing protein 10-like, transcript variant X3
# 2 calcyphosin-like protein, transcript variant X3
# 3 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 4 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 5 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
# 6 pre-B-cell leukemia transcription factor 1-like, transcript variant X11
#   pair_vs_HC gene_name
# 1 CH, HH, CC ADAM10
# 2 CH, HH, CC CAPSL
# 3 CH, HH, CC PBX1
# 4 CH, HH, CC PBX1
# 5 CH, HH, CC PBX1
# 6 CH, HH, CC PBX1
#   process                                                   notes GO.IDs
# 1 cell signaling, adhesion, migration                             GO:0007219
# 2 calcium ion binding                                             NA
# 3 regulates embryonic development and cellular differention       GO:0048568
# 4 regulates embryonic development and cellular differention       GO:0009887
# 5 regulates embryonic development and cellular differention       GO:0048666
# 6 regulates embryonic development and cellular differention       GO:0048666
#   GOslim     Term
# 1 GO:0023052 signaling
# 2 NA         NA
# 3 GO:0048856 anatomical structure development
# 4 GO:0048856 anatomical structure development
# 5 GO:0030154 cell differentiation
# 6 GO:0048856 cell differentiation

# %%
xx <- as.list(GOBPPARENTS)
xx <- xx[!is.na(xx)]
if (length(xx) > 0) {
  goids <- xx[[725]]
  term <- GOTERM[[goids[1]]]
  cat("GO ID:", GOID(term), "\n")
  cat("Term:", Term(term), "\n")
  cat("Definition:", Definition(term), "\n")
  cat("Ontology:", Ontology(term), "\n")
}
# Out:
# GO ID: GO:0043436
# Term: oxoacid metabolic process
# Definition: The chemical reactions and pathways involving any oxoacid; an oxoacid is a compound which contains oxygen, at least one other element, and at least one hydrogen bound to oxygen, and which produces a conjugate base by loss of positive hydrogen ion(s) (hydrons).
# Ontology: BP

# %%
# Convert GOBPPARENTS to a list
go_parents <- as.list(GOBPPARENTS)

# Define your list of GO IDs
my_go_ids <- dmgs$GO.IDs

# Initialize an empty data frame to store the results
results <- data.frame(GO_ID = character(), Parent_GO_ID = character(), Term = character(), stringsAsFactors = FALSE)

# Loop through each of your GO IDs
for (go_id in my_go_ids) {
  # Find the parent GO IDs for the current GO ID
  parent_ids <- names(go_parents[go_parents == go_id])
  
  # Loop through each parent GO ID
  for (parent_id in parent_ids) {
    # Get the term for the parent GO ID
    term_data <- AnnotationDb::select(GOTERM, keys = parent_id, columns = c("TERM"))
    term <- term_data$TERM
    
    # Add the result to the data frame
    results <- rbind(results, data.frame(GO_ID = go_id, Parent_GO_ID = parent_id, Term = term))
  }
}

# Print the results
print(results)
# Out:
# Error in loadNamespace(x): there is no package called ‘AnnotationDb’
# Traceback:
#
# 1. loadNamespace(x)
# 2. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 3. withOneRestart(expr, restarts[[1L]])
# 4. doWithOneRestart(return(expr), restart)
